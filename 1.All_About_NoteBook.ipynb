# %%
print("helo")

# %%
import time
for i in range(10):
    print(i)
    time.sleep(1)

# %%
# %sql
select date_format(current_date(),'dd-MM-yyyy') as current_date;

# %% [markdown]
# #magic commands

# %%
# %sh
ls -l
ls
date

# %%
print(spark)
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
print(spark)

# %%
df = spark.range(10)
df.display()
df.show()
